# %%
import pandas as pd
from matplotlib import pyplot as plt

#C:\Users\Vedra\Desktop\RuterOblig
Ruter = pd.read_csv('Ruter_data.csv', delimiter=';',index_col=0)
print(Ruter.head(10))

# %%
Ruter.describe()
# Out:
#        Linjeretning  Kjøretøy_Kapasitet  Passasjerer_Ombord
# count   6000.000000         6000.000000         6000.000000
# mean       0.492000          104.712167            4.512833
# std        0.499978           24.225196            6.735730
# min        0.000000           33.000000          -39.000000
# 25%        0.000000           80.000000            0.000000
# 50%        0.000000          106.000000            3.000000
# 75%        1.000000          112.000000            7.000000
# max        1.000000          151.000000           64.000000

# %%
Kjor=Ruter[Ruter['Holdeplass_Til'] == 'Ringstabekkveien']
Kjor.head()
# Out:
#                                        Dato  Fylke Område Kommune  \
# TurId
# 15001-2020-07-28T15:54:00+02:00  28/07/2020  Viken   Vest   Bærum
# 15008-2020-08-01T16:09:00+02:00  01/08/2020  Viken   Vest   Bærum
# 15002-2020-07-26T13:24:00+02:00  26/07/2020  Viken   Vest   Bærum
# 15010-2020-08-21T19:05:00+02:00  21/08/2020  Viken   Vest   Bærum
# 15005-2020-07-30T15:45:00+02:00  30/07/2020  Viken   Vest   Bærum
#
#                                 Holdeplass_Fra    Holdeplass_Til Linjetype  \
# TurId
# 15001-2020-07-28T15:54:00+02:00  Stabekk skole  Ringstabekkveien     Lokal
# 15008-2020-08-01T16:09:00+02:00  Stabekk skole  Ringstabekkveien     Lokal
# 15002-2020-07-26T13:24:00+02:00  Stabekk skole  Ringstabekkveien     Lokal
# 15010-2020-08-21T19:05:00+02:00        Skallum  Ringstabekkveien     Lokal
# 15005-2020-07-30T15:45:00+02:00        Skallum  Ringstabekkveien     Lokal
#
#                                 Linjefylke Linjenavn  Linjeretning  \
# TurId
# ...

# %%
Ruter.dtypes
# Out:
# Dato                                         object
# Fylke                                        object
# Område                                       object
# Kommune                                      object
# Holdeplass_Fra                               object
# Holdeplass_Til                               object
# Linjetype                                    object
# Linjefylke                                   object
# Linjenavn                                    object
# Linjeretning                                  int64
# Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra     object
# Tidspunkt_Faktisk_Avgang_Holdeplass_Fra      object
# Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra    object
# Tidspunkt_Planlagt_Avgang_Holdeplass_Fra     object
# Kjøretøy_Kapasitet                            int64
# Passasjerer_Ombord                            int64
# dtype: object

# %%
Kjor=Ruter[Ruter['Holdeplass_Fra'] == 'Stallkroa']
Kjor.head()
# Out:
#                                        Dato  Fylke Område Kommune  \
# TurId
# 14003-2020-08-12T20:02:00+02:00  12/08/2020  Viken   Vest   Bærum
# 14007-2020-07-17T11:24:00+02:00  17/07/2020  Viken   Vest   Bærum
#
#                                 Holdeplass_Fra Holdeplass_Til Linjetype  \
# TurId
# 14003-2020-08-12T20:02:00+02:00      Stallkroa       Øvrevoll     Lokal
# 14007-2020-07-17T11:24:00+02:00      Stallkroa     Nordjordet     Lokal
#
#                                 Linjefylke Linjenavn  Linjeretning  \
# TurId
# 14003-2020-08-12T20:02:00+02:00      Viken       140             0
# 14007-2020-07-17T11:24:00+02:00      Viken       140             1
#
#                                 Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# TurId
# 14003-2020-08-12T20:02:00+02:00                                 20:26:26
# 14007-2020-07-17T11:24:00+02:00                                 11:38:45
#
#                                 Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# TurId
# ...

# %%
Kjor=Ruter[Ruter['Holdeplass_Fra'] == 'Stallkroa']
(Ruter['Dato'] <= '20.08.2020')
Kjor.head()
# Out:
#                                        Dato  Fylke Område Kommune  \
# TurId
# 14003-2020-08-12T20:02:00+02:00  12/08/2020  Viken   Vest   Bærum
# 14007-2020-07-17T11:24:00+02:00  17/07/2020  Viken   Vest   Bærum
#
#                                 Holdeplass_Fra Holdeplass_Til Linjetype  \
# TurId
# 14003-2020-08-12T20:02:00+02:00      Stallkroa       Øvrevoll     Lokal
# 14007-2020-07-17T11:24:00+02:00      Stallkroa     Nordjordet     Lokal
#
#                                 Linjefylke Linjenavn  Linjeretning  \
# TurId
# 14003-2020-08-12T20:02:00+02:00      Viken       140             0
# 14007-2020-07-17T11:24:00+02:00      Viken       140             1
#
#                                 Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# TurId
# 14003-2020-08-12T20:02:00+02:00                                 20:26:26
# 14007-2020-07-17T11:24:00+02:00                                 11:38:45
#
#                                 Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# TurId
# ...

# %%
Ruter['date_time'] = pd.to_datetime(Ruter['Dato']) # Ads a new date colum soo we can sort by date.

# %%
Tur= Ruter[(Ruter['Linjenavn'] == '150') &
                       (Ruter['date_time'] >='17/07/2020') &
                       (Ruter['date_time'] < '18/07/2020')]
Tur
# Out:
#                                        Dato  Fylke Område Kommune  \
# TurId
# 15005-2020-07-17T18:00:00+02:00  17/07/2020  Viken   Vest   Bærum
# 15007-2020-07-17T07:15:00+02:00  17/07/2020  Viken   Vest   Bærum
# 15004-2020-07-17T05:39:00+02:00  17/07/2020  Viken   Vest   Bærum
#
#                                                        Holdeplass_Fra  \
# TurId
# 15005-2020-07-17T18:00:00+02:00                      Nadderud stadion
# 15007-2020-07-17T07:15:00+02:00                             Gruvemyra
# 15004-2020-07-17T05:39:00+02:00  Bekkestua bussterminal (Plattform C)
#
#                                 Holdeplass_Til Linjetype Linjefylke Linjenavn  \
# TurId
# 15005-2020-07-17T18:00:00+02:00    Øygardveien     Lokal      Viken       150
# 15007-2020-07-17T07:15:00+02:00       Gullhaug     Lokal      Viken       150
# 15004-2020-07-17T05:39:00+02:00  Stabekk skole     Lokal      Viken       150
#
#                                  Linjeretning  \
# TurId
# ...

# %%
Linje_gropup=Ruter.groupby(['Linjenavn'])# Groups the Lines
Linje_gropup

# %%
Linje_gropup['Passasjerer_Ombord'].sum() #Adds the passangers in every line up
# Out:
# Linjenavn
# 100     3442
# 110     2139
# 110E      95
# 115E      52
# 120      521
#         ...
# 5N         4
# 60       525
# 67         4
# 74       203
# 91       174
# Name: Passasjerer_Ombord, Length: 150, dtype: int64

# %%
Tur= Ruter[(Ruter['Holdeplass_Til'] == 'Stallkroa') &
                       (Ruter['Dato'] <='31/08/20') &
                       (Ruter['Dato'] > '21/08/2020')]
Tur
Station_Totals = pd.DataFrame(Linje_gropup['Passasjerer_Ombord'].sum())
Station_Totals.sort_values(ascending=False,by='Passasjerer_Ombord',inplace=True)
Station_Totals
# Out:
#            Passasjerer_Ombord
# Linjenavn
# 100                      3442
# 110                      2139
# 390                      1764
# 380                      1300
# 250                      1253
# ...                       ...
# 3676                       -9
# 145                       -13
# 41                        -15
# 245                       -19
# 215A                      -48
#
# [150 rows x 1 columns]

# %%
Station_Totals.head(5)  # Shows the top five lines with passanger numbers
# Out:
#            Passasjerer_Ombord
# Linjenavn
# 100                      3442
# 110                      2139
# 390                      1764
# 380                      1300
# 250                      1253

# %%
Station_Totals.head(30).plot(kind='bar',rot=90) # Graph of the top 30 lines and sum of passangers
# Out:
# <AxesSubplot:xlabel='Linjenavn'>

# %%
Uketur= Ruter[(Ruter['Kommune'] == 'Bærum') &
                       (Ruter['date_time'] >='16/08/2020') &
                       (Ruter['date_time'] < '15/08/2020')]
Uketur
# Out:
# Empty DataFrame
# Columns: [Dato, Fylke, Område, Kommune, Holdeplass_Fra, Holdeplass_Til, Linjetype, Linjefylke, Linjenavn, Linjeretning, Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra, Tidspunkt_Faktisk_Avgang_Holdeplass_Fra, Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra, Tidspunkt_Planlagt_Avgang_Holdeplass_Fra, Kjøretøy_Kapasitet, Passasjerer_Ombord, date_time]
# Index: []

# %%
Uketur= Ruter[(Ruter['Holdeplass_Fra'] == 'Nordliveien') & (Ruter['Holdeplass_Til'] == 'Tjernsmyr') & 
                       (Ruter['date_time'] >='01/06/2020') &
                       (Ruter['date_time'] < '11/08/2020') & (Ruter['Passasjerer_Ombord'] > 0)]
Uketur
# Out:
#                                        Dato  Fylke Område Kommune  \
# TurId
# 15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
#
#                                 Holdeplass_Fra Holdeplass_Til Linjetype  \
# TurId
# 15006-2020-08-10T10:24:00+02:00    Nordliveien      Tjernsmyr     Lokal
#
#                                 Linjefylke Linjenavn  Linjeretning  \
# TurId
# 15006-2020-08-10T10:24:00+02:00      Viken       150             0
#
#                                 Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# TurId
# 15006-2020-08-10T10:24:00+02:00                                 10:53:53
#
#                                 Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# TurId
# 15006-2020-08-10T10:24:00+02:00                                10:53:59
#
#                                 Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# TurId
# 15006-2020-08-10T10:24:00+02:00                                  10:53:00
#
# ...

# %%
Ruter.describe()
# Out:
#        Linjeretning  Kjøretøy_Kapasitet  Passasjerer_Ombord
# count   6000.000000         6000.000000         6000.000000
# mean       0.492000          104.712167            4.512833
# std        0.499978           24.225196            6.735730
# min        0.000000           33.000000          -39.000000
# 25%        0.000000           80.000000            0.000000
# 50%        0.000000          106.000000            3.000000
# 75%        1.000000          112.000000            7.000000
# max        1.000000          151.000000           64.000000

# %%
#Boardings in the morning rush. Line 100
Turer= Ruter[(Ruter['Linjenavn'] == '100') & (Ruter['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] <= '09:00:00') & 
           (Ruter['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] > '08:00:00')  & (Ruter['Passasjerer_Ombord'] > 0)]
                 
Turer
Turer.plot(x ='Tidspunkt_Faktisk_Avgang_Holdeplass_Fra', y='Passasjerer_Ombord')
# Out:
# C:\Users\Vedra\anaconda3\envs\dave3625\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'>

# %%
TurerDato= Ruter[(Ruter['Linjenavn'] == '100') & (Ruter['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] <= '09:00:00') & 
(Ruter['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] > '08:00:00')  & (Ruter['Passasjerer_Ombord'] > 0)& 
(Ruter['date_time'] < '15/08/2020')]
TurerDato.plot.scatter(x='Passasjerer_Ombord', y='Tidspunkt_Faktisk_Avgang_Holdeplass_Fra', title='Bordings in the rush hour. Date 15.08.20  ')
# Out:
# <AxesSubplot:title={'center':'Bordings in the rush hour. Date 15.08.20  '}, xlabel='Passasjerer_Ombord', ylabel='Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'>

# %%
Late= Ruter[(Ruter['Linjenavn'] == '100') & 
            (Ruter['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] <= '09:00:00') & 
            (Ruter['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] > '08:00:00')  &
            (Ruter['Passasjerer_Ombord'] > 0)&
            (Ruter['Tidspunkt_Planlagt_Avgang_Holdeplass_Fra']<= '09:00:00') &
            (Ruter['Tidspunkt_Planlagt_Avgang_Holdeplass_Fra'] > '08:00:00')
           ]
Late

      #Passengers on 100   bus between 0800-0900 in the rushour 
   
Late.plot(kind='bar', y=['Linjenavn','Passasjerer_Ombord'], x='Tidspunkt_Faktisk_Avgang_Holdeplass_Fra')

plt.show()

# %%
Kapasitet_gropup=Ruter.groupby(['Kommune'])# Groups the Lines

# %%
Kapasitet_gropup['Kjøretøy_Kapasitet'].sum()
# Out:
# Kommune
# Alna                  26970
# Asker                 33646
# Aurskog-Høland        10146
# Bjerke                21527
# Bærum                 79182
# Drammen                 672
# Eidsvoll              14392
# Enebakk               12240
# Frogner                4044
# Gamle Oslo            27801
# Gjerdrum              10062
# Grorud                 9218
# Grünerløkka           11826
# Hurdal                  880
# Indre Østfold          1908
# Lier                   1680
# Lillestrøm           121606
# Lørenskog             53915
# Nannestad             24777
# Nes                   10860
# Nittedal              28672
# Nordmarka               852
# Nordre Aker            1768
# Nordre Follo           1520
# Nordstrand             6654
# Rælingen              21669
# Sagene                 4630
# Sentrum                9692
# St.Hanshaugen          5090
# Stovner               12376
# Søndre Nordstrand      2344
# Ullensaker            37102
# Ullern                 9963
# ...

# %%
totKap = pd.DataFrame(Kapasitet_gropup['Kjøretøy_Kapasitet'].sum())
totKap.sort_values(ascending=False,by='Kjøretøy_Kapasitet',inplace=True)
totKap
# Out:
#                    Kjøretøy_Kapasitet
# Kommune
# Lillestrøm                     121606
# Bærum                           79182
# Lørenskog                       53915
# Ullensaker                      37102
# Asker                           33646
# Nittedal                        28672
# Gamle Oslo                      27801
# Alna                            26970
# Nannestad                       24777
# Rælingen                        21669
# Bjerke                          21527
# Eidsvoll                        14392
# Stovner                         12376
# Enebakk                         12240
# Grünerløkka                     11826
# Nes                             10860
# Aurskog-Høland                  10146
# Gjerdrum                        10062
# Ullern                           9963
# Sentrum                          9692
# Grorud                           9218
# Vestre Aker                      8589
# Nordstrand                       6654
# ...

# %%
totKap.head(10)
#Capacity in top 10 counties
# Out:
#             Kjøretøy_Kapasitet
# Kommune
# Lillestrøm              121606
# Bærum                    79182
# Lørenskog                53915
# Ullensaker               37102
# Asker                    33646
# Nittedal                 28672
# Gamle Oslo               27801
# Alna                     26970
# Nannestad                24777
# Rælingen                 21669

# %%
totKap.head(10).plot(kind='pie',subplots=True) # Graph of the top 30 lines and sum of passangers
#Capacity in top 10 counties
# Out:
# array([<AxesSubplot:ylabel='Kjøretøy_Kapasitet'>], dtype=object)
